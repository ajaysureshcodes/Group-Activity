# %%
import numpy as np
x = np.array([[8,9,10],[11,12,13]])
x.shape = (3,2)
print(x)
# Out:
# [[ 8  9]
#  [10 11]
#  [12 13]]

# %%
y =np.array ([[8,9],[10,11],[12,13]])
print(y)
print('Sliced array is ', y[:2,1])
# Out:
# [[ 8  9]
#  [10 11]
#  [12 13]]
# Sliced array is  [ 9 11]

# %%
data={'Country':['Russia','Columbia','Chilie','Equador','Nigeria'],'Rank':[121,40,100,130,11]}
country_data = pd.DataFrame(data)
print(country_data)
# Out:
#     Country  Rank
# 0    Russia   121
# 1  Columbia    40
# 2    Chilie   100
# 3   Equador   130
# 4   Nigeria    11

# %%
import pandas as pd
sample_data = [['Russia',121], ['Columbia',40],['Chile',100],['Ecuador',130], ['Nigeria',11]]
colmn = ['Country', 'Rank']
country_data = pd.DataFrame(data = sample_data, columns = colmn)
country_data
# Out:
#     Country  Rank
# 0    Russia   121
# 1  Columbia    40
# 2     Chile   100
# 3   Ecuador   130
# 4   Nigeria    11

# %%
import pandas as pd
data = pd.read_csv('/content/diabetes_model.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               614 non-null    int64
#  1   Glucose                   614 non-null    int64
#  2   BloodPressure             614 non-null    int64
#  3   SkinThickness             614 non-null    int64
#  4   Insulin                   614 non-null    int64
#  5   BMI                       614 non-null    float64
#  6   DiabetesPedigreeFunction  614 non-null    float64
#  7   Age                       614 non-null    int64
#  8   Outcome                   614 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 43.3 KB

# %%
glu_age = data.loc[45:60, ['Glucose', 'Age']]

# %%
glu_age
# Out:
#     Glucose  Age
# 45      137   21
# 46      145   70
# 47      113   22
# 48       96   27
# 49      131   26
# 50      113   21
# 51      120   34
# 52       95   24
# 53      155   46
# 54      100   46
# 55      184   49
# 56       90   29
# 57      142   61
# 58      125   27
# 59      101   26
# 60      188   22

# %%
data.value_counts(data['BloodPressure'] > 120)
num = (data['BloodPressure']>120).sum()
print('Number of patients with BP greater than 120 is ', num)
# Out:
# Number of patients with BP greater than 120 is  1

# %%
sumbp = data[data['BloodPressure']>120]['BloodPressure'].count()
print('Number of patients with BP greater than 120 is ', sumbp)
# Out:
# Number of patients with BP greater than 120 is  1

# %%
print('Minimum value of Insulin is ', data['Insulin'].min())
print('Maximum value of Insulin is ', data['Insulin'].max())
# Out:
# Minimum value of Insulin is  0
# Maximum value of Insulin is  846

# %%
import matplotlib.pyplot as plt
plt.hist(data['Age'])
plt.show()

# %%
plt.scatter(data['BMI'], data['Glucose'])
plt.title('Scatter plot of BMI vs Glucose')
plt.xlabel('BMI')
plt.ylabel('Glucose')
plt.show()
